# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import spacy
from spacy import displacy
import networkx

# %%
# load spacy model (name entity recognition)
NER = spacy.load('en_core_web_sm')

# %%
# Load chapters
import os

# get all chapters in data dir
all_chapters = [b for b in os.scandir('data') if '.txt' in b.name]

# %%
#all_chapters

# %%
chapter = all_chapters[0]
chapter_text = open(chapter).read()
chap_doc = NER(chapter_text)

# %%
# viz identified entities (most wont be correct names or anything, but its a start)
displacy.render(chap_doc[0:1000], style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chapter 100Sacrifice
# Standing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  in Rea’s home,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zorian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  ignored the curious gazes leveled at him from Rea and Haslush and kept silent, calmly considering things. A
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  questions swam through his head. Why were these
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  gathered in Rea’s house, despite the fact they shouldn’t even know about each other? Why did Rea think he could help in this situation and what were their enemies even thinking when they orchestrated this kidnapping? Was this some kind of strike against him and Zach? Why not go after all of his classmates, then?</br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raynie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  did not give him a lot of time to ponder those questions, though, and took his silence as a sign she should keep going.</br>“My family doesn’t live in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cyoria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , so I didn’t even know it happened at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# . It wasn’t until my family discovered some signs the kidnappers might have originated from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cyoria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  that they contacted me,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     several days later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and asked me for help,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raynie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  explained quietly. “I was shocked. Shocked that it happened, and… umm…”</br>She fumbled with her words for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a few seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  before falling into an awkward silence and lowering her head even further. She looked quite pitiable at the moment.</br>“That they asked for your help with this?”
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zorian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  tried.</br>She flinched slightly and gave him a shocked look for a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# . Guilt, sadness, and confusion emanated from her in an equal mix. However, she quickly schooled her expression and cleared her throat with a trace of panic.</br>“Y-Yes, exactly! I’m just an academy student, what can I even do?” she said hurriedly. “I want to help my little brother, of course, but this is way above me! So I… contacted the police about it… and they eventually pointed me at detective
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ikzeteri
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  here, who agreed to help. And… here we are, I guess.” She took a deep breath after finishing her explanation and gave Zorian a disbelieving, but slightly hopeful look. “No offense,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zorian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , but I’m still not sure how you can help me with this.”</br>“Neither am I,” Zorian told her honestly.</br>He could help, of course. How he should go about doing that, however, was something he couldn’t decide on at the moment.</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raynie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s expression immediately dimmed after his admission, but he didn’t let that bother him. He couldn’t ruin all their plans just to assure her everything would be alright.</br>He glanced at Rea and she glanced back at him, completely unconcerned with whether or not she had judged him wrong. What exactly gave her the confidence that he was someone who could make a difference here? No matter how he wracked his head, he couldn’t figure it out.</br>“You’re pretty calm about this,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haslush
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  commented from the side, giving him a shrewd look.</br>“Panicking wouldn’t help anyone,”
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zorian
#     <span style="font-size: 0.8em; fon

# %%
# Read Char names
character_df = pd.read_csv('charDF.csv')
character_df
# Out:
#     Unnamed: 0         character
# 0            0  Zorian Kazinski
# 1            1      Zach Noveda
# 2            2         Red Robe
# 3            3   Cikan Kazinski
# 4            4   Andir Kazinski
# ..         ...               ...
# 82          82       Kilnfather
# 83          83       Stonechild
# 84          84        Violeteye
# 85          85         Panaxeth
# 86          86       ↑ chapter 2
#
# [87 rows x 2 columns]

# %%
# create a first name column
import re
character_df['character_firstname'] = character_df['character'].apply(lambda x: x.split(" ", 1)[0])

# %%
# get named entities per sentence
sent_entity_df = []

#loop thru each sentence, store named entity list for each
for sent in chap_doc.sents:
    sent_entities = [ent.text for ent in sent.ents]
    sent_entity_df.append({"sentence": sent, "entities": sent_entities})

sent_entity_df = pd.DataFrame(sent_entity_df)

# %%
#filter out non characters

def filter_char(ent_list, char_df):
    return [ent for ent in ent_list
            if ent in list(char_df.character) 
            or ent in list(char_df.character_firstname)
    ]

# %%
filter_char(["Zorian", "2", "Xvim"], character_df)
# Out:
# ['Zorian', 'Xvim']

# %%
sent_entity_df['character_entities'] = sent_entity_df['entities'].apply(lambda x: filter_char(x, character_df))

#remove sentences without character entities
sent_entity_df_filtered = sent_entity_df[sent_entity_df['character_entities'].map(len) > 0]
sent_entity_df_filtered
# Out:
#                                               sentence  \
# 0    (Chapter, 100Sacrifice, \n, Standing, in, Rea,...
# 5    (Why, not, go, after, all, of, his, classmates...
# 7    (It, was, n’t, until, my, family, discovered, ...
# 13                                  (Zorian, tried, .)
# 24   (“, No, offense, ,, Zorian, ,, but, I, ’m, sti...
# ..                                                 ...
# 416  (Raynie, loudly, gasped, and, swayed, unsteadi...
# 420  (The, dimensional, gates, floating, above, the...
# 425  (If, Raynie, was, doing, this, alone, ,, she, ...
# 434  (\n, -, break, -, \n, Sitting, next, to, a, ta...
# 436    (\n, “, We, found, them, ,, ”, Zorian, said, .)
#
#                                      entities character_entities
# 0    [Chapter 100Sacrifice\nStanding, Zorian]           [Zorian]
# 5                                    [Raynie]           [Raynie]
# 7        [Cyoria, several days later, Raynie]           [Raynie]
# 13                                   [Zorian]           [Zorian]
# 24                                   [Zorian]           [Zorian]
# ..                                        ...                ...
# 416                          [Raynie, dozens]           [Raynie]
# 420                          [Haslush, three]          [Haslush]
# 425                                  [Raynie]           [Raynie]
# 434                            [Xvim, Zorian]     [Xvim, Zorian]
# 436                                  [Zorian]           [Zorian]
#
# [130 rows x 3 columns]

# %%
# only first names
sent_entity_df_filtered['character_firstname'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [ent.split(" ", 1)[0] for ent in x])
# Out:
# C:\Users\boon\AppData\Local\Temp\ipykernel_15460\2233797906.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_entity_df_filtered['character_firstname'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [ent.split(" ", 1)[0] for ent in x])

# %%
pd.reset_option('^display.', silent=True)
sent_entity_df_filtered
# Out:
#                                               sentence  \
# 0    (Chapter, 100Sacrifice, \n, Standing, in, Rea,...
# 5    (Why, not, go, after, all, of, his, classmates...
# 7    (It, was, n’t, until, my, family, discovered, ...
# 13                                  (Zorian, tried, .)
# 24   (“, No, offense, ,, Zorian, ,, but, I, ’m, sti...
# ..                                                 ...
# 416  (Raynie, loudly, gasped, and, swayed, unsteadi...
# 420  (The, dimensional, gates, floating, above, the...
# 425  (If, Raynie, was, doing, this, alone, ,, she, ...
# 434  (\n, -, break, -, \n, Sitting, next, to, a, ta...
# 436    (\n, “, We, found, them, ,, ”, Zorian, said, .)
#
#                                      entities character_entities  \
# 0    [Chapter 100Sacrifice\nStanding, Zorian]           [Zorian]
# 5                                    [Raynie]           [Raynie]
# 7        [Cyoria, several days later, Raynie]           [Raynie]
# 13                                   [Zorian]           [Zorian]
# 24                                   [Zorian]           [Zorian]
# ..                                        ...                ...
# 416                          [Raynie, dozens]           [Raynie]
# 420                          [Haslush, three]          [Haslush]
# 425                                  [Raynie]           [Raynie]
# 434                            [Xvim, Zorian]     [Xvim, Zorian]
# 436                                  [Zorian]           [Zorian]
#
#     character_firstname
# 0              [Zorian]
# 5              [Raynie]
# 7              [Raynie]
# 13             [Zorian]
# 24             [Zorian]
# ..                  ...
# 416            [Raynie]
# 420           [Haslush]
# 425            [Raynie]
# 434      [Xvim, Zorian]
# 436            [Zorian]
#
# [130 rows x 4 columns]

# %%
#create relationships
window_size = 5
relationships = []

for i in range(sent_entity_df_filtered.index[-1]):
    end_i = min(i+5, sent_entity_df_filtered.index[-1])
    char_list = sum((sent_entity_df_filtered.loc[i: end_i].character_entities), [])

    #remove duplicates if found
    char_unique = [char_list[i] for i in range(len(char_list)) if (i==0) or char_list != char_list[i-1]]

    if len(char_unique)>1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({'source': a, 'target': b})

# %%
relationship_df = pd.DataFrame(relationships)
relationship_df
# Out:
#      source  target
# 0    Zorian  Raynie
# 1    Raynie  Raynie
# 2    Raynie  Raynie
# 3    Raynie  Raynie
# 4    Raynie  Raynie
# ..      ...     ...
# 529  Zorian  Zorian
# 530    Xvim  Zorian
# 531  Zorian  Zorian
# 532    Xvim  Zorian
# 533  Zorian  Zorian
#
# [534 rows x 2 columns]
